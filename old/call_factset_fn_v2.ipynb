# %% [markdown]
# # <center>Gathering Supply Chain Data<center>

# %% [markdown]
# - Date: March 2019
# - Author: Minsu Yeom, CFA, FRM

# %%
import os
import numpy as np
import pandas as pd
import bamboolib as bam
import xlwings as xw
from datetime import date
from mlfinance.utils.misc import get_letter, get_last_bday

# %%
# Reload all modules (except those excluded by %aimport) every time before executing the Python code typed.
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # 1. Loading Equity Universe

# %%
universe = pd.read_table('./mlfinance/dataset/eqy_universe_gt50mm.txt',
                         header=1,
                         names=[
                             'Identifier', 'Name', 'Revenue', 'Company Type',
                             'Business Description', 'FactSet Industry',
                             'Crunchbase Category(BETA)',
                             'Crunchbase Rank(BETA)', 'Ultimate Parent Name',
                             'Fiscal Year End', 'Country', 'Website'
                         ], 
                         parse_dates = ['Fiscal Year End']
                        )

# %% [markdown]
# #### Change dtypes properly

# %%
universe.loc[:, 'Revenue'] = pd.to_numeric(universe.loc[:,'Revenue'], errors='coerce')
universe.loc[:, 'Fiscal Year End'] = pd.to_datetime(universe.loc[:, 'Fiscal Year End'], errors='coerce')

# %%
universe.dtypes
# Out:
# Identifier                           object
# Name                                 object
# Revenue                             float64
# Company Type                         object
# Business Description                 object
# FactSet Industry                     object
# Crunchbase Category(BETA)            object
# Crunchbase Rank(BETA)                object
# Ultimate Parent Name                 object
# Fiscal Year End              datetime64[ns]
# Country                              object
# Website                              object
# dtype: object

# %% [markdown]
# #### Setting the minimum market cap criteria in USD mm
# - Reset the index.

# %%
min_market_cap = 200
universe = universe.loc[universe.loc[:, 'Revenue'] >= min_market_cap, :]
universe = universe.reset_index(drop = True)

# %% [markdown]
# ### Missing value analysis

# %% [markdown]
# - Looks all good.

# %%
universe.isna().sum()
# Out:
# Identifier                     0
# Name                           0
# Revenue                        0
# Company Type                   0
# Business Description           0
# FactSet Industry               0
# Crunchbase Category(BETA)      0
# Crunchbase Rank(BETA)          0
# Ultimate Parent Name           0
# Fiscal Year End                1
# Country                        0
# Website                      127
# dtype: int64

# %% [markdown]
# #### Launch Excel with making it sure FastSet add-ins enabled
# - `fdswFixExcel.exe` enables the add-ins.
# - `retcode`: 0 if runs fine. 1 if any error.

# %%
import subprocess
retcode = subprocess.run(['C:/Program Files (x86)/FactSet/fdswFixExcel.exe'])

# %%
# subprocess.CompletedProcess.check_returncode

# %% [markdown]
# #### Load company tickers

# %%
# # tickers = ['AAPL-US', 'GOOGL-US', 'AMZN-US']
# tickers = universe.loc[0:999, 'Identifier'].to_list()

# %%
# len(tickers)

# %% [markdown]
# #### Set an Excel header

# %%
header_meta = ['date', 'ticker',  'relationship']
header_fcst = ['rel_comp_tic', 'rel_comp_nm', 'no_overlap', 'pct_overlap', 'revenue_dependence', 'source', 'prtr_rel']
header = header_meta + header_fcst

# %% [markdown]
# #### Set Excel column names and Excel ranges for a relationship data set

# %% [markdown]
# Column names

# %%
# Excel column names for meta data
meta_col = {}
for i, col_nm in enumerate(header_meta):
    meta_col[col_nm] = get_letter(i)

# Excel column names for FactSet data to be downloaded
fcst_start_col = get_letter(len(header_meta))
fcst_end_col = get_letter(len(header_fcst)-1, letter = fcst_start_col)

# %% [markdown]
# The whole data range

# %%
per_company_rows = 500
batch_sz = 10
data_height = batch_sz * per_company_rows
data_range = 'A1:' + get_letter(len(header)-1) + str(data_height)

# %% [markdown]
# #### FactSet settings

# %%
#wb=xw.books

# SUPL: Suppliers. 
# CUST: Customers
# PRTR: Partners
# COMP: Competitors
# It's FactSet's codes.
relationships = ['SUPL', 'CUST', 'PRTR', 'COMP']

# =FDS("GOOGL-US", "FF_COMPANY_RELATIONSHIP(SUPL,PUB,Ticker,ALL,ALL)")
fds_fn = '", "TRANSPOSE(FF_COMPANY_RELATIONSHIP('
fds_param = ',PUB,Ticker,ALL,ALL))")'

# %% [markdown]
# #### Load company relationship data from FactSet and write it in an Excel workbook by
# - Writing `=FDS()` directly an Excel sheet named as in `relationships`
# - Allocating `rows` rows for each company

# %%
def get_company_relationships(tickers):
    ws = {}
    fcst_ranges = {}

    # Iterate over ['SUPL', 'CUST', 'PRTR', 'COMP']
    for i, rel in enumerate(relationships):
        ws[rel] = xw.sheets.add(rel)    # Create a sheet per relationship

        # Load company relationship data and write it in the workbook.
        for j, ticker in enumerate(tickers):
            fcst_ranges[ticker] = '{:s}{:d}:{:s}{:d}'.format(fcst_start_col, j*per_company_rows+1, fcst_end_col, (j+1)*per_company_rows)
            ws[rel].range(fcst_ranges[ticker]).formula_array = '=FDSR("' + ticker + fds_fn + rel + fds_param
            ticker_col = get_letter(header_meta.index('ticker'))
            ticker_range = '{:s}{:d}:{:s}{:d}'.format(ticker_col, j*per_company_rows+1, ticker_col, (j+1)*per_company_rows)
            ws[rel].range(ticker_range).value = ticker


        for meta_type, col_nm in meta_col.items():
            meta_range = '{:s}{:d}:{:s}{:d}'.format(meta_col[meta_type], 1, meta_col[meta_type], data_height)
            meta_value = get_last_bday() if meta_type == 'date' else rel if meta_type == 'relationship' else '-'

            # We don't write `ticker` here because it's already filled.
            if meta_type != 'ticker':
                ws[rel].range(meta_range).value = meta_value
    
    return ws

# %% [markdown]
# #### Extract data from each sheet in `ws` and merge it into `df`
# - We also do: resetting the index and setting the column names.

# %%
universe
# Out:
#       Identifier                             Name     Revenue    Company Type  \
# 0         DRI-DE                 1&1 Drillisch AG  4320.78600  Public Company
# 1       MOBIL-NG                           11 Plc   455.41678  Public Company
# 2         2GB-DE                     2G Energy AG   247.49089  Public Company
# 3         III-GB                     3i Group plc   506.57350  Public Company
# 4        FOUR-GB               4imprint Group plc   860.84400  Public Company
# ...          ...                              ...         ...             ...
# 14230      ZM-US  Zoom Video Communications, Inc.   622.65800  Public Company
# 14231      ZS-US                    Zscaler, Inc.   302.83600  Public Company
# 14232    ZUMZ-US                      Zumiez Inc.  1034.12900  Public Company
# 14233     ZUO-US                      Zuora, Inc.   276.05700  Public Company
# 14234    ZNGA-US                       Zynga Inc.  1321.65900  Public Company
#
#                                     Business Description  \
# 0      1&1 Drillisch AG provides telecommunication se...
# 1      11 Plc operates as an oil and gas distribution...
# 2      2G Energy AG operates as a holding company, wh...
# 3      3i Group Plc operates as a private equity and ...
# 4      4imprint Group Plc engages in the provision of...
# ...                                                  ...
# 14230  Zoom Video Communications, Inc. engages in the...
# 14231  Zscaler, Inc. engages in the provision of clou...
# 14232  Zumiez, Inc. engages in retailing apparel, foo...
# 14233  Zuora, Inc. operates as an online subscription...
# 14234  Zynga, Inc. provides social game services. It ...
#
#                      FactSet Industry Crunchbase Category(BETA)  \
# 0        Specialty Telecommunications                         -
# 1              Oil Refining/Marketing                         -
# 2                  Electric Utilities                         -
# 3                 Investment Managers                         -
# 4      Advertising/Marketing Services                         -
# ...                               ...                       ...
# 14230               Packaged Software                         -
# 14231               Packaged Software                         -
# 14232         Apparel/Footwear Retail                         -
# 14233               Packaged Software                         -
# 14234      Internet Software/Services                         -
#
#       Crunchbase Rank(BETA)             Ultimate Parent Name Fiscal Year End  \
# 0                         -               United Internet AG      2018-12-31
# 1                         -                        NIPCO Plc      2018-12-31
# 2                         -                     2G Energy AG      2018-12-31
# 3                         -                     3i Group plc      2019-03-31
# 4                         -               4imprint Group plc      2019-12-28
# ...                     ...                              ...             ...
# 14230                     -  Zoom Video Communications, Inc.      2020-01-31
# 14231                     -                    Zscaler, Inc.      2019-07-31
# 14232                     -                      Zumiez Inc.      2020-02-01
# 14233                     -                      Zuora, Inc.      2020-01-31
# 14234                     -                       Zynga Inc.      2019-12-31
#
#               Country                        Website
# 0             Germany  http://www.1und1-drillisch.de
# 1             Nigeria          http://www.11plc.com/
# 2             Germany                  http://2-g.de
# 3      United Kingdom             http://3igroup.com
# 4      United Kingdom            http://4imprint.com
# ...               ...                            ...
# 14230   United States             http://www.zoom.us
# 14231   United States         http://www.zscaler.com
# 14232   United States          http://www.zumiez.com
# 14233   United States           http://www.zuora.com
# 14234   United States           http://www.zynga.com
#
# [14235 rows x 12 columns]

# %%
ws_list = []
for idx in range(0, 30, batch_sz):
    print(idx, end = ' ')
    tickers = universe.loc[idx:idx+batch_sz-1, 'Identifier'].to_list()
#     tickers = df2.loc[idx:idx+batch_sz-1, 'ticker'].to_list()
    ws = get_company_relationships(tickers)
    
    for sheet in ws.keys():
        ws_list.append(pd.DataFrame(ws[sheet].range(data_range).value))
#         ws[sheet].delete()

df = pd.concat(ws_list)
df = df.reset_index(drop = True)
df.columns = header
# Out:
# 0 10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-2b866ef676eb> in <module>
#       4     tickers = universe.loc[idx:idx+batch_sz-1, 'Identifier'].to_list()
#       5 #     tickers = df2.loc[idx:idx+batch_sz-1, 'ticker'].to_list()
# ----> 6     ws = get_company_relationships(tickers)
#       7
#       8     for sheet in ws.keys():
#
# <ipython-input-15-992991a9748c> in get_company_relationships(tickers)
#       5     # Iterate over ['SUPL', 'CUST', 'PRTR', 'COMP']
#       6     for i, rel in enumerate(relationships):
# ----> 7         ws[rel] = xw.sheets.add(rel)    # Create a sheet per relationship
#       8
#       9         # Load company relationship data and write it in the workbook.
#
# ~\Anaconda3\lib\site-packages\xlwings\main.py in add(self, name, before, after)
#    2931         if name is not None:
#    2932             if name.lower() in (s.name.lower() for s in self):
# -> 2933                 raise ValueError("Sheet named '%s' already present in workbook" % name)
#    2934         if before is not None and not isinstance(before, Sheet):
#    2935             before = self(before)
#
# ValueError: Sheet named 'SUPL' already present in workbook

# %%
df
# Out:
#              date   ticker relationship rel_comp_tic  \
# 0      2020-03-20   DRI-DE         SUPL       TEF-ES
# 1      2020-03-20   DRI-DE         SUPL       VOD-GB
# 2      2020-03-20   DRI-DE         SUPL       SAP-DE
# 3      2020-03-20   DRI-DE         SUPL       SGE-GB
# 4      2020-03-20   DRI-DE         SUPL       O2D-DE
# ...           ...      ...          ...          ...
# 179995 2020-03-20  ADVI-FR         COMP         None
# 179996 2020-03-20  ADVI-FR         COMP         None
# 179997 2020-03-20  ADVI-FR         COMP         None
# 179998 2020-03-20  ADVI-FR         COMP         None
# 179999 2020-03-20  ADVI-FR         COMP         None
#
#                               rel_comp_nm no_overlap pct_overlap  \
# 0                           Telefonica SA    5 of 27          19
# 1                      Vodafone Group Plc    4 of 31          13
# 2                                  SAP SE    0 of 93           0
# 3                          Sage Group plc    0 of 22           0
# 4       Telefonica Deutschland Holding AG     4 of 6          67
# ...                                   ...        ...         ...
# 179995                               None       None        None
# 179996                               None       None        None
# 179997                               None       None        None
# 179998                               None       None        None
# 179999                               None       None        None
#
#        revenue_dependence   source prtr_rel
# 0                    None   Direct     None
# 1                    None   Direct     None
# 2                    None   Direct     None
# 3                    None   Direct     None
# 4                    None  Reverse     None
# ...                   ...      ...      ...
# 179995               None     None     None
# 179996               None     None     None
# 179997               None     None     None
# 179998               None     None     None
# 179999               None     None     None
#
# [180000 rows x 10 columns]

# %%
# df.to_pickle('./mlfinance/dataset/company_relationships_1-1000.pkl')

# %%
df2 = pd.read_pickle('./mlfinance/dataset/company_relationships_1-1000.pkl')

# %%
df.loc[3500:3510,:]
# Out:
#            date  ticker relationship  \
# 3500 2020-03-20  AFE-ZA         SUPL
# 3501 2020-03-20  AFE-ZA         SUPL
# 3502 2020-03-20  AFE-ZA         SUPL
# 3503 2020-03-20  AFE-ZA         SUPL
# 3504 2020-03-20  AFE-ZA         SUPL
# 3505 2020-03-20  AFE-ZA         SUPL
# 3506 2020-03-20  AFE-ZA         SUPL
# 3507 2020-03-20  AFE-ZA         SUPL
# 3508 2020-03-20  AFE-ZA         SUPL
# 3509 2020-03-20  AFE-ZA         SUPL
# 3510 2020-03-20  AFE-ZA         SUPL
#
#                                     rel_comp_tic rel_comp_nm no_overlap  \
# 3500                                      ACT-ZA        None       None
# 3501  AfroCentric Investment Corporation Limited        None       None
# 3502                                     0 of 21        None       None
# 3503                                           0        None       None
# 3504                                        None        None       None
# 3505                                     Reverse        None       None
# 3506                                        None        None       None
# 3507                                                    None       None
# 3508                                        None        None       None
# 3509                                        None        None       None
# 3510                                        None        None       None
#
#      pct_overlap revenue_dependence source prtr_rel
# 3500        None               None   None     None
# 3501        None               None   None     None
# 3502        None               None   None     None
# 3503        None               None   None     None
# 3504        None               None   None     None
# 3505        None               None   None     None
# 3506        None               None   None     None
# 3507        None               None   None     None
# 3508        None               None   None     None
# 3509        None               None   None     None
# 3510        None               None   None     None

# %%
df.loc[df.rel_comp_tic=='Reverse', :]
# Out:
#              date     ticker relationship rel_comp_tic rel_comp_nm no_overlap  \
# 3505   2020-03-20     AFE-ZA         SUPL      Reverse        None       None
# 4505   2020-03-20    7745-JP         SUPL      Reverse        None       None
# 6505   2020-03-20     III-GB         CUST      Reverse        None       None
# 9005   2020-03-20    5391-JP         CUST      Reverse        None       None
# 15505  2020-03-20   MOBIL-NG         COMP      Reverse        None       None
# 17005  2020-03-20    FOUR-GB         COMP      Reverse        None       None
# 19505  2020-03-20    7745-JP         COMP      Reverse        None       None
# 23505  2020-03-20     AAK-SE         SUPL      Reverse        None       None
# 29505  2020-03-20    AHCS-QA         CUST      Reverse        None       None
# 36005  2020-03-20     APE-AU         COMP      Reverse        None       None
# 40005  2020-03-20     ARL-DE         SUPL      Reverse        None       None
# 45505  2020-03-20     ABE-PL         CUST      Reverse        None       None
# 47505  2020-03-20    2670-JP         CUST      Reverse        None       None
# 50505  2020-03-20     ABE-PL         PRTR      Reverse        None       None
# 55505  2020-03-20     ABE-PL         COMP      Reverse        None       None
# 64005  2020-03-20    ADIB-AE         SUPL      Reverse        None       None
# 67005  2020-03-20    ABSP-ZA         CUST      Reverse        None       None
# 73505  2020-03-20    ADCB-AE         PRTR      Reverse        None       None
# 77005  2020-03-20    ABSP-ZA         COMP      Reverse        None       None
# 87505  2020-03-20   ACCEL-NL         CUST      Reverse        None       None
# 88005  2020-03-20     AX1-AU         CUST      Reverse        None       None
# 101005 2020-03-20     ACE-IT         SUPL      Reverse        None       None
# 102505 2020-03-20    ACKB-BE         SUPL      Reverse        None       None
# 103005 2020-03-20    8572-JP         SUPL      Reverse        None       None
# 106505 2020-03-20     ACX-ES         CUST      Reverse        None       None
# 107505 2020-03-20    ACKB-BE         CUST      Reverse        None       None
# 117505 2020-03-20    ACKB-BE         COMP      Reverse        None       None
# 118005 2020-03-20    8572-JP         COMP      Reverse        None       None
# 119505 2020-03-20     ACS-IT         COMP      Reverse        None       None
# 124005 2020-03-20  ANOD.B-SE         SUPL      Reverse        None       None
# 138505 2020-03-20  ALIF.B-SE         COMP      Reverse        None       None
# 139505 2020-03-20  ADDT.B-SE         COMP      Reverse        None       None
# 156005 2020-03-20    4401-JP         COMP      Reverse        None       None
# 159505 2020-03-20     ADL-DE         COMP      Reverse        None       None
# 161005 2020-03-20   ADRS2-HR         SUPL      Reverse        None       None
# 166005 2020-03-20   ADRS2-HR         CUST      Reverse        None       None
# 169505 2020-03-20    ADVI-FR         CUST      Reverse        None       None
# 171505 2020-03-20     ADV-DE         PRTR      Reverse        None       None
# 173005 2020-03-20     ATC-KW         PRTR      Reverse        None       None
# 175505 2020-03-20     ADM-GB         COMP      Reverse        None       None
# 179005 2020-03-20    6030-JP         COMP      Reverse        None       None
#
#        pct_overlap revenue_dependence source prtr_rel
# 3505          None               None   None     None
# 4505          None               None   None     None
# 6505          None               None   None     None
# 9005          None               None   None     None
# 15505         None               None   None     None
# 17005         None               None   None     None
# 19505         None               None   None     None
# 23505         None               None   None     None
# 29505         None               None   None     None
# 36005         None               None   None     None
# 40005         None               None   None     None
# 45505         None               None   None     None
# 47505         None               None   None     None
# 50505         None               None   None     None
# 55505         None               None   None     None
# 64005         None               None   None     None
# 67005         None               None   None     None
# 73505         None               None   None     None
# 77005         None               None   None     None
# 87505         None               None   None     None
# 88005         None               None   None     None
# 101005        None               None   None     None
# 102505        None               None   None     None
# 103005        None               None   None     None
# 106505        None               None   None     None
# 107505        None               None   None     None
# 117505        None               None   None     None
# 118005        None               None   None     None
# 119505        None               None   None     None
# 124005        None               None   None     None
# 138505        None               None   None     None
# 139505        None               None   None     None
# 156005        None               None   None     None
# 159505        None               None   None     None
# 161005        None               None   None     None
# 166005        None               None   None     None
# 169505        None               None   None     None
# 171505        None               None   None     None
# 173005        None               None   None     None
# 175505        None               None   None     None
# 179005        None               None   None     None

# %%
df3 = df2.loc[:, ['ticker', 'relationship', 'rel_comp_tic']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-968996063c36> in <module>
# ----> 1 df3 = df2.loc[:, ['ticker', 'relationship', 'rel_comp_tic']]
#
# NameError: name 'df2' is not defined

# %%
df3
# bamboolib live code export
df3 = df3.dropna(subset=['rel_comp_tic'])
df3 = df3.groupby(['ticker', 'relationship']).agg(rel_comp_tic_nunique=('rel_comp_tic', 'nunique')).reset_index()
df3
# Out:
#           ticker relationship rel_comp_tic
# 0         DRI-DE         SUPL       TEF-ES
# 1         DRI-DE         SUPL       VOD-GB
# 2         DRI-DE         SUPL       SAP-DE
# 3         DRI-DE         SUPL       SGE-GB
# 4         DRI-DE         SUPL       O2D-DE
# ...          ...          ...          ...
# 3999995  8530-JP         COMP         None
# 3999996  8530-JP         COMP         None
# 3999997  8530-JP         COMP         None
# 3999998  8530-JP         COMP         None
# 3999999  8530-JP         COMP         None
#
# [4000000 rows x 3 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\ipywidgets\widgets\widget.py in _handle_msg(self, msg)
#     674                 if 'buffer_paths' in data:
#     675                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676                 self.set_state(state)
#     677
#     678         # Handle a state request.
#
# ~\Anaconda3\lib\site-packages\ipywidgets\widgets\widget.py in set_state(self, sync_data)
#     543                     from_json = self.trait_metadata(name, 'from_json',
#     544                                                     self._trait_from_json)
# --> 545                     self.set_trait(name, from_json(sync_data[name], self))
#     546
#     547     def send(self, content, buffers=None):
#
# ~\Anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# ~\Anaconda3\lib\site-packages\traitlets\traitlets.py in hold_trait_notifications(self)
#    1129                 for changes in cache.values():
#    1130                     for change in changes:
# -> 1131                         self.notify_change(change)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
#
# ~\Anaconda3\lib\site-packages\ipywidgets\widgets\widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~\Anaconda3\lib\site-packages\traitlets\traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# ~\Anaconda3\lib\site-packages\plotly\basewidget.py in _handler_js2py_relayout(self, change)
#     641         # Perform relayout
#     642         # ----------------
# --> 643         self.plotly_relayout(relayout_data=relayout_data, source_view_id=source_view_id)
#     644
#     645         self._js2py_relayout = None
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in plotly_relayout(self, relayout_data, **kwargs)
#    2034             self._send_relayout_msg(relayout_changes, **msg_kwargs)
#    2035
# -> 2036             self._dispatch_layout_change_callbacks(relayout_changes)
#    2037
#    2038     def _perform_plotly_relayout(self, relayout_data):
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in _dispatch_layout_change_callbacks(self, relayout_data)
#    2227                 dispatch_obj = self.layout[path_tuple]
#    2228                 if isinstance(dispatch_obj, BasePlotlyType):
# -> 2229                     dispatch_obj._dispatch_change_callbacks(changed_paths)
#    2230
#    2231     def _dispatch_trace_change_callbacks(self, restyle_data, trace_indexes):
#
# ~\Anaconda3\lib\site-packages\plotly\basedatatypes.py in _dispatch_change_callbacks(self, changed_paths)
#    4061
#    4062                 for callback in callbacks:
# -> 4063                     callback(self, *callback_args)
#    4064
#    4065     def on_change(self, callback, *args, **kwargs):
#
# ~\Anaconda3\lib\site-packages\bamboolib\edaviz_helper.cp37-win_amd64.pyd in bamboolib.edaviz_helper.interactive_hist_small.handle_zoom()
#
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'int'

# %%
df.to_feather('./mlfinance/dataset/company_relationships_1-1000.feather')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-42-0ceb7047e3f9> in <module>
# ----> 1 df.to_feather('./mlfinance/dataset/company_relationships_1-1000.feather')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_feather(self, fname)
#    2150         from pandas.io.feather_format import to_feather
#    2151
# -> 2152         to_feather(self, fname)
#    2153
#    2154     def to_parquet(
#
# ~\Anaconda3\lib\site-packages\pandas\io\feather_format.py in to_feather(df, path)
#      21
#      22     """
# ---> 23     import_optional_dependency("pyarrow")
#      24     from pyarrow import feather
#      25
#
# ~\Anaconda3\lib\site-packages\pandas\compat\_optional.py in import_optional_dependency(name, extra, raise_on_missing, on_version)
#      91     except ImportError:
#      92         if raise_on_missing:
# ---> 93             raise ImportError(message.format(name=name, extra=extra)) from None
#      94         else:
#      95             return None
#
# ImportError: Missing optional dependency 'pyarrow'.  Use pip or conda to install pyarrow.

# %% [markdown]
# ## ----------------- The end of work -------------------

# %% [markdown]
# #### Set ranges in each sheet for each company in `tickers`
# - e.g. `cell_ranges['AAPL-US'] <- 'D1:J1000'

# %%
height = 1000
fcst_data_ranges = {}
for i, name in enumerate(rel_names):
    print(i+1, name)

for j, ticker in enumerate(tickers):
    fcst_data_ranges[ticker] = 'A{:d}:G{:d}'.format(j*height+1, (j+1)*height)
    print(fcst_data_ranges[ticker])
#     print('A{:d}:G{:d}'.format(j*height+1, (j+1)*height))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-47ffe995b50e> in <module>
#       1 height = 1000
#       2 fcst_data_ranges = {}
# ----> 3 for i, name in enumerate(rel_names):
#       4     print(i+1, name)
#       5
#
# NameError: name 'rel_names' is not defined

# %% [markdown]
# #### `xw.App` launches Excel.
# - With `visible` False, it runs in the background

# %%
app = xw.App(visible=True)

# %%
xw.books

# %%
bk

# %%
book = app.books.open(os.getcwd() + '/test.xlsx')
sheet = book.sheets['Suppliers']
sheet.range('A1').value = 12

# %%
sheets = {}
sheets['customers'] = book.sheets['Customers']
sheets['suppliers'] = book.sheets['Suppliers']
sheets['Partners'] = book.sheets['Partners']

# %%
sheets['customers']

# %%
import win32com.client as win32
from win32com.client import makepy

# %%
path = 'C:/Program Files (x86)/FactSet/fdsxl32_x64.xll'
xl = win32.gencache.EnsureDispatch('Excel.Application')
xl.Visible = True
xl.DisplayAlerts=False
xl.RegisterXLL(path)
# xl.COMAddIns("PowerlinkCOMAddIn.COMAddIn").Connect = True
#xl.COMAddIns('C:/Program Files (x86)/FactSe|t/COMShim_x64.dll').Installed = True
#xl.COMAddIns(4)
for i in range(1, xl.COMAddIns.Count+1):
    print("Index: ", i, xl.COMAddIns(i).Description, xl.COMAddIns(i).Connect)
    if xl.COMAddIns(i).Description == "FactSet Office COM Add-In":
        print("xl.COMAddIns({:d}).Description: {:s}".format(i, xl.COMAddIns(i).Description))

wb = xl.Workbooks.Open(os.getcwd() + '/test.xlsx')
ws = wb.Worksheets('Sheet1')

# %%
xl.COMAddIns.Count

# %%
import subprocess
import xlwings as xw
retcode = subprocess.call("C:/Program Files (x86)/FactSet/fdswFixExcel.exe")
#print(retcode)
#xl = win32.gencache.EnsureDispatch('Excel.Application')
#xl.Visible = True
#xl.DisplayAlerts = False
print(xw.books.active.name)
#wb = xl.Workbooks.Open(os.getcwd() + '/test.xlsx')
#ws = wb.Worksheets('Sheet1')

# %%
import xlwings

# %%
xl2 = win32.gencache.EnsureDispatch("Excel.Application")
xl2.Visible = True
wb2 = xl.Workbooks.Add(1)
xl2.AddIns("FactSet Office COM Add-In").Installed = False
xl2.AddIns("FactSet Office COM Add-In").Installed = True

# %%
xl.run('FDS', 'a', 'b', 'c', 'd')
