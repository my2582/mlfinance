# %%
from newsplease import NewsPlease

# %%
article = NewsPlease.from_url('https://www.nytimes.com/2017/02/23/us/politics/cpac-stephen-bannon-reince-priebus.html?hp')
print(article.title)
# Out:
# Stephen Bannon Reassures Conservatives Uneasy About Trump

# %%
article.maintext
# Out:
# 'Ms. Conway said the stories of disarray in the White House, including recent accounts that she has been sidelined lately, were nothing more than tiresome palace intrigue. And without naming names, she said the attacks directed at her were really desperate attacks against the president by political enemies still sore about the election.\n“To try to remove me from the equation would remove one of his voices and one of his trusted aides. And that would be hurtful to him,” she said. “They didn’t see this coming. They weren’t prepared for this result — even though they all ran around and said: ‘We’re a divided country! We’re a divided country!’”\nIt was not as if the support for Mr. Trump, who will speak to the conference Friday morning, is not enthusiastic.\n“I always said he’s not a stupid man. And if he has the right people around him he’s going to do the right thing,” said Daniel Cirucci of Cherry Hill, N.J., who was standing in line on Thursday evening to listen to Vice President Mike Pence, a conservative he said he deeply admired. “I think he realizes the enormity of the job,” Mr. Cirucci added. “Now does that mean Trump is going to stop being Trump? No.”\nThese should be good times for conservatives — and much of the time they are. They control not just the White House but both houses of Congress and appear on the verge of regaining a majority on the Supreme Court. They have not dominated so many state governments in close to a century.\nBut part of the subtext of CPAC this year has been how conservative leaders are trying to smooth out the rougher edges of their movement, not all of which involve Mr. Trump.'

# %%
article.get_dict()
# Out:
# {'authors': ['Jeremy W. Peters'],
#  'date_download': datetime.datetime(2020, 8, 11, 11, 24, 16),
#  'date_modify': None,
#  'date_publish': datetime.datetime(2017, 2, 24, 2, 7, 6),
#  'description': 'The president’s chief strategist vowed that the “deconstruction of the administrative state” has begun, in a speech at the Conservative Political Action Conference.',
#  'filename': 'https%3A%2F%2Fwww.nytimes.com%2F2017%2F02%2F23%2Fus%2Fpolitics%2Fcpac-stephen-bannon-reince-priebus.html%3Fhp.json',
#  'image_url': 'https://static01.nyt.com/images/2017/02/24/us/24cpac1/24cpac1-facebookJumbo.jpg',
#  'language': 'en',
#  'localpath': None,
#  'maintext': 'Ms. Conway said the stories of disarray in the White House, including recent accounts that she has been sidelined lately, were nothing more than tiresome palace intrigue. And without naming names, she said the attacks directed at her were really desperate attacks against the president by political enemies still sore about the election.\n“To try to remove me from the equation would remove one of his voices and one of his trusted aides. And that would be hurtful to him,” she said. “They didn’t see this coming. They weren’t prepared for this result — even though they all ran around and said: ‘We’re a divided country! We’re a divided country!’”\nIt was not as if the support for Mr. Trump, who will speak to the conference Friday morning, is not enthusiastic.\n“I always said he’s not a stupid man. And if he has the right people around him he’s going to do the right thing,” said Daniel Cirucci of Cherry Hill, N.J., who was standing in line on Thursday evening to listen to Vice President Mike Pence, a conservative he said he deeply admired. “I think he realizes the enormity of the job,” Mr. Cirucci added. “Now does that mean Trump is going to stop being Trump? No.”\nThese should be good times for conservatives — and much of the time they are. They control not just the White House but both houses of Congress and appear on the verge of regaining a majority on the Supreme Court. They have not dominated so many state governments in close to a century.\nBut part of the subtext of CPAC this year has been how conservative leaders are trying to smooth out the rougher edges of their movement, not all of which involve Mr. Trump.',
#  'source_domain': 'www.nytimes.com',
#  'text': None,
#  'title': 'Stephen Bannon Reassures Conservatives Uneasy About Trump',
#  'title_page': None,
#  'title_rss': None,
#  'url': 'https://www.nytimes.com/2017/02/23/us/politics/cpac-stephen-bannon-reince-priebus.html?hp'}

# %%
article = NewsPlease.from_url('https://feeds.finance.yahoo.com/rss/2.0/headline?s=AAPL&region=US&lang=en-US')
print(article.title)
# Out:
# Yahoo! Finance: AAPL News

# %%
article.get_dict()
# Out:
# {'authors': [],
#  'date_download': datetime.datetime(2020, 8, 11, 11, 32, 46),
#  'date_modify': None,
#  'date_publish': None,
#  'description': None,
#  'filename': 'https%3A%2F%2Ffeeds.finance.yahoo.com%2Frss%2F2.0%2Fheadline%3Fs%3DAAPL%26region%3DUS%26lang%3Den-US.json',
#  'image_url': 'https://feeds.finance.yahoo.com/rss/2.0/headline?s=AAPL&region=US&lang=en-US',
#  'language': 'en',
#  'localpath': None,
#  'maintext': None,
#  'source_domain': 'feeds.finance.yahoo.com',
#  'text': None,
#  'title': 'Yahoo! Finance: AAPL News',
#  'title_page': None,
#  'title_rss': None,
#  'url': 'https://feeds.finance.yahoo.com/rss/2.0/headline?s=AAPL&region=US&lang=en-US'}

# %%
from stocknews import StockNews

# %%
sn = StockNews(['AAPL'])

# %%
sn.read_rss()
# Out:
#                                     guid stock  \
# 0   79b906c1-4285-3b78-85a3-52fbe1e734f6  AAPL
# 1   e41cff71-ab3c-3c35-a757-8ddafbaafad0  AAPL
# 2   220bca48-3f5c-37eb-aa47-f8e223f8e697  AAPL
# 3   65b53896-faf4-3a06-9d0d-a63cf3c83192  AAPL
# 4   54859d16-fa03-3196-a3ee-64b659d3c3fd  AAPL
# ..                                   ...   ...
# 65  05a6b9d2-54c5-32ae-8754-74f2aeca8568  AAPL
# 66  404f8d29-5615-3f90-a352-0d913366cddb  AAPL
# 67  91ce0086-7fc6-37da-ab89-db68fec33bf2  AAPL
# 68  57e1dd07-9cdf-390f-8f0a-149d8ae0dd6a  AAPL
# 69  771f27db-c74f-3c93-852d-64cc86dc13da  AAPL
#
#                                                 title  \
# 0   3 Diverse Large-Cap Stocks to Buy Now to Boost...
# 1   As Apple Nears $2 Trillion, Its Share of S&P 5...
# 2   US STOCKS-Wall St ends higher as investors eye...
# 3   Dow Jones Stocks To Buy And Watch In August 20...
# 4   Apple Inc. stock rises Tuesday, outperforms ma...
# ..                                                ...
# 65  Apple Stock Nears $2 Trillion Valuation. Analy...
# 66  Dow Jones Leads, Nasdaq Lags As Market Weighs ...
# 67  Facebook, Microsoft gripes with Apple&#39;s Ap...
# 68  Dow Jones Jumps 275 Points On Trump Executive ...
# 69  Why Apple iPhone Sales Could Take a Huge Hit F...
#
#                                               summary  \
# 0   Investors should consider adding a few large-c...
# 1   (Bloomberg) -- The world gawked two years ago ...
# 2   Wall Street ended higher after a choppy sessio...
# 3   The Dow Jones Industrial Average closed out Ju...
# 4   COMPANY CLOSE UPDATES  Terrence Horan Shares o...
# ..                                                ...
# 65  As  (AAPL) inches closer to a $2 trillion valu...
# 66  The Dow Jones Industrial Average hit new sessi...
# 67  Facebook and Microsoft's grievances over how t...
# 68  The major stock indexes were mixed on Presiden...
# 69  TF International analyst Ming-Chi Kuo thinks A...
#
#                           published           p_date  sentiment_summary  \
# 0   Tue, 04 Aug 2020 23:44:11 +0000  AAPL_2020-08-04             0.4522
# 1   Tue, 04 Aug 2020 22:51:51 +0000  AAPL_2020-08-04             0.9974
# 2   Tue, 04 Aug 2020 21:02:25 +0000  AAPL_2020-08-04             0.6757
# 3   Tue, 04 Aug 2020 20:50:33 +0000  AAPL_2020-08-04             0.7579
# 4   Tue, 04 Aug 2020 20:25:00 +0000  AAPL_2020-08-04             0.7003
# ..                              ...              ...                ...
# 65  Mon, 10 Aug 2020 17:24:00 +0000  AAPL_2020-08-10             0.0790
# 66  Mon, 10 Aug 2020 16:25:08 +0000  AAPL_2020-08-10            -0.5994
# 67  Mon, 10 Aug 2020 16:21:12 +0000  AAPL_2020-08-10            -0.3612
# 68  Mon, 10 Aug 2020 16:20:01 +0000  AAPL_2020-08-10            -0.0772
# 69  Mon, 10 Aug 2020 16:16:00 +0000  AAPL_2020-08-10            -0.4019
#
#     sentiment_title
# 0            0.4019
# 1            0.2960
# 2            0.0000
# 3            0.0000
# 4            0.0000
# ..              ...
# 65           0.0000
# 66          -0.6369
# 67           0.0000
# 68           0.0000
# 69          -0.3182
#
# [70 rows x 8 columns]
